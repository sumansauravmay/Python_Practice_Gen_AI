# %% [markdown]
# <a href="https://colab.research.google.com/github/sumansauravmay/Python_Practice_Gen_AI/blob/main/Python_Sesson_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list, tuple, set, dictionary
newList=[12,23,45,12];
print(newList);
newList.append(35)
# Out:
# [12, 23, 45, 12]

# %%
print(set(newList))
# Out:
# {35, 12, 45, 23}

# %%
print(tuple(newList))
# Out:
# (12, 23, 45, 12, 35)

# %%
print(newList);
# Out:
# [12, 23, 45, 12, 35]

# %%
newtuple=(23,343,53,67);
print(list(newtuple));
# Out:
# [23, 343, 53, 67]

# %%
newSet={34, 45, 34, 56,87};
print(newSet);
# Out:
# {56, 34, 45, 87}

# %%
newSet.add(21);
print(newSet)
# Out:
# {34, 45, 21, 87, 56}

# %%
print(newSet.pop())
# Out:
# 34

# %%
print(newSet)
# Out:
# {45, 21, 87, 56}

# %%
print(newSet[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2138/2210363909.py in <cell line: 0>()
# ----> 1 print(newSet[2])
#
# TypeError: 'set' object is not subscriptable

# %%
# print unique number in one line.
listOne=[56,78,56,78,12,13];
print(list(set(listOne)))
# Out:
# [56, 12, 13, 78]
